# %%
import os
from data.adapter import load_gwhd_df
import pandas as pd

DATASET_ROOT_DIR = '/home/js/gwhd_2021-2'
TRAIN_SUBSET = 'competition_train.csv'

train_df_annotations = load_gwhd_df(os.path.join(DATASET_ROOT_DIR, TRAIN_SUBSET))
train_df_images = pd.read_csv(os.path.join(DATASET_ROOT_DIR, TRAIN_SUBSET))
train_df_annotations
# Out:
#                                                image_name  \
# 0       0007634580386bd39d4d0d24df58893c3bb967e12d6fc0...
# 1       0007634580386bd39d4d0d24df58893c3bb967e12d6fc0...
# 2       0007634580386bd39d4d0d24df58893c3bb967e12d6fc0...
# 3       0007634580386bd39d4d0d24df58893c3bb967e12d6fc0...
# 4       0007634580386bd39d4d0d24df58893c3bb967e12d6fc0...
# ...                                                   ...
# 163625  fff24daa579e1e2752e320f7f8c6b654249a66d1f18cb2...
# 163626  fff24daa579e1e2752e320f7f8c6b654249a66d1f18cb2...
# 163627  fff24daa579e1e2752e320f7f8c6b654249a66d1f18cb2...
# 163628  fff24daa579e1e2752e320f7f8c6b654249a66d1f18cb2...
# 163629  fff24daa579e1e2752e320f7f8c6b654249a66d1f18cb2...
#
#                                               BoxesString      domain  \
# 0       936 4 977 82;966 0 1023 114;665 9 795 79;877 0...  Arvalis_11
# 1       936 4 977 82;966 0 1023 114;665 9 795 79;877 0...  Arvalis_11
# 2       936 4 977 82;966 0 1023 114;665 9 795 79;877 0...  Arvalis_11
# 3       936 4 977 82;966 0 1023 114;665 9 795 79;877 0...  Arvalis_11
# 4       936 4 977 82;966 0 1023 114;665 9 795 79;877 0...  Arvalis_11
# ...                                                   ...         ...
# 163625  402 0 491 114;556 35 605 149;500 130 567 186;7...   Arvalis_8
# 163626  402 0 491 114;556 35 605 149;500 130 567 186;7...   Arvalis_8
# 163627  402 0 491 114;556 35 605 149;500 130 567 186;7...   Arvalis_8
# 163628  402 0 491 114;556 35 605 149;500 130 567 186;7...   Arvalis_8
# 163629  402 0 491 114;556 35 605 149;500 130 567 186;7...   Arvalis_8
#
#         image_id  class_id  class_name              Box   xmin   ymin    xmax  \
# 0              0       0.0  wheat_head     936 4 977 82  936.0    4.0   977.0
# 1              0       0.0  wheat_head   966 0 1023 114  966.0    0.0  1023.0
# 2              0       0.0  wheat_head     665 9 795 79  665.0    9.0   795.0
# 3              0       0.0  wheat_head     877 0 958 20  877.0    0.0   958.0
# 4              0       0.0  wheat_head    742 0 852 132  742.0    0.0   852.0
# ...          ...       ...         ...              ...    ...    ...     ...
# 163625      3653       0.0  wheat_head  235 910 283 937  235.0  910.0   283.0
# 163626      3653       0.0  wheat_head  961 530 998 572  961.0  530.0   998.0
# 163627      3653       0.0  wheat_head  980 470 997 522  980.0  470.0   997.0
# 163628      3653       0.0  wheat_head  787 452 851 488  787.0  452.0   851.0
# 163629      3653       0.0  wheat_head    777 67 811 91  777.0   67.0   811.0
#
#          ymax  has_annotation
# 0        82.0            True
# 1       114.0            True
# 2        79.0            True
# 3        20.0            True
# 4       132.0            True
# ...       ...             ...
# 163625  937.0            True
# 163626  572.0            True
# 163627  522.0            True
# 163628  488.0            True
# 163629   91.0            True
#
# [163630 rows x 12 columns]

# %%
domain_to_devl_stage = {
        'Arvalis_1' : 'Postflowering',
        'Arvalis_2' : 'Filling',
        'Arvalis_3' : 'Filling-ripening',
        'Arvalis_4' : 'Filling',
        'Arvalis_5' : 'Filling',
        'Arvalis_6' : 'Filling-ripening',
        'Arvalis_7' : 'Filling-ripening',
        'Arvalis_8' : 'Filling-ripening',
        'Arvalis_9' : 'Ripening',
        'Arvalis_10' : 'Filling',
        'Arvalis_11' : 'Filling',
        'Arvalis_12' : 'Filling',
        'ETHZ_1' : 'Filling',
        'Inrae_1' : 'Filling-ripening',
        'NMBU_1' : 'Filling',
        'NMBU_2' : 'Ripening',
        'Rres_1' : 'Filling-ripening',
        'ULiège-GxABT_1' : 'Ripening'
    }

# %%
import numpy as np

# %%
domains_names, value_counts = np.unique(train_df_images['domain'], return_counts=True)
print(domains_names)
value_counts
# Out:
# ['Arvalis_1' 'Arvalis_10' 'Arvalis_11' 'Arvalis_12' 'Arvalis_2'
#  'Arvalis_3' 'Arvalis_4' 'Arvalis_5' 'Arvalis_6' 'Arvalis_7' 'Arvalis_8'
#  'Arvalis_9' 'ETHZ_1' 'Inrae_1' 'NMBU_1' 'NMBU_2' 'Rres_1'
#  'ULiège-GxABT_1']
# array([ 66,  58,  60,  29, 401, 588, 204, 448, 160,  24,  20,  32, 746,
#        176,  82,  98, 432,  30])

# %%
weights = 1 / value_counts
weights
# Out:
# array([0.01515152, 0.01724138, 0.01666667, 0.03448276, 0.00249377,
#        0.00170068, 0.00490196, 0.00223214, 0.00625   , 0.04166667,
#        0.05      , 0.03125   , 0.00134048, 0.00568182, 0.01219512,
#        0.01020408, 0.00231481, 0.03333333])

# %%
train_df_images['weight'] = train_df_images['domain'].apply(lambda x: weights[np.where(domains_names == x)[0][0]])
train_df_images
# Out:
#                                              image_name  \
# 0     0007634580386bd39d4d0d24df58893c3bb967e12d6fc0...
# 1     00417fc37a35f14ce3044bf2ae6c76d19bf42a426a9403...
# 2     004b381a051838dc0cc8ff293e09823faa1dd6f26e82ff...
# 3     004ccec5da561b85d8b05ed11c071ac9ef3af5c8c9a1d6...
# 4     006f18cc577457d0d0b987d1af19e5568541cc5f84e143...
# ...                                                 ...
# 3649  ff93ccb206f49b83feacc20d245862ed41336ecb04a417...
# 3650  ffa790ef2ab2aeed5bb6f4f54cc0f909f23f2352fe3ba3...
# 3651  ffbf32e12b7d53aa6d7ceeaca94e1ab9706800b2cef9bb...
# 3652  ffc7fee025ebc4e763d0e250fdf6ee07666396882584e3...
# 3653  fff24daa579e1e2752e320f7f8c6b654249a66d1f18cb2...
#
#                                             BoxesString      domain    weight
# 0     936 4 977 82;966 0 1023 114;665 9 795 79;877 0...  Arvalis_11  0.016667
# 1     931 370 1002 512;698 935 770 1024;47 51 135 14...   Arvalis_3  0.001701
# 2     528 623 567 703;651 421 755 468;282 287 331 42...      ETHZ_1  0.001340
# 3     353 362 440 484;36 326 97 382;199 105 274 172;...   Arvalis_2  0.002494
# 4     4 5 60 43;0 34 18 73;52 63 90 127;259 0 338 68...      NMBU_1  0.012195
# ...                                                 ...         ...       ...
# 3649  439 106 501 162;516 181 556 259;118 131 170 16...   Arvalis_5  0.002232
# 3650  126 847 256 936;0 141 55 201;282 911 331 941;9...   Arvalis_3  0.001701
# 3651  293 116 375 191;399 933 443 1024;374 110 467 1...   Arvalis_5  0.002232
# 3652  809 772 995 848;130 868 260 1024;950 58 1019 2...  Arvalis_11  0.016667
# 3653  402 0 491 114;556 35 605 149;500 130 567 186;7...   Arvalis_8  0.050000
#
# [3654 rows x 4 columns]

# %%
from torch.utils.data import WeightedRandomSampler
from torch.utils.data import DataLoader

# %%
from data.adapter import GwhdToYoloAdapter
from yolov7.dataset import Yolov7Dataset
from yolov7.dataset import yolov7_collate_fn
train_adapter = GwhdToYoloAdapter(os.path.join(DATASET_ROOT_DIR, 'images'), train_df_annotations, None)
yolo_train_ds = Yolov7Dataset(train_adapter)

# %%
print(len(train_df_images))
print(len(yolo_train_ds))
sampler = WeightedRandomSampler(
    weights=train_df_images['weight'],
    num_samples=len(train_df_images['weight']),
    replacement=True
)
dl = DataLoader(yolo_train_ds, batch_size=1, sampler=sampler)
# Out:
# 3654
# 3654

# %%
from tqdm import tqdm
def print_dataloader(dl, n_batches=3):
    domain_counts = {
        'Arvalis_1' : 0,
        'Arvalis_2' : 0,
        'Arvalis_3' : 0,
        'Arvalis_4' : 0,
        'Arvalis_5' : 0,
        'Arvalis_6' : 0,
        'Arvalis_7' : 0,
        'Arvalis_8' : 0,
        'Arvalis_9' : 0,
        'Arvalis_10' : 0,
        'Arvalis_11' : 0,
        'Arvalis_12' : 0,
        'ETHZ_1' : 0,
        'Inrae_1' : 0,
        'NMBU_1' : 0,
        'NMBU_2' : 0,
        'Rres_1' : 0,
        'ULiège-GxABT_1' : 0
    }
    counter = 0
    indices_seen = []
    for batch in tqdm(dl):
        images, labels, indices, sizes = batch
        indices_seen.extend([int(idx) for idx in indices])
        for idx in indices:
            domain_counts[train_df_images.iloc[int(idx)]['domain']] += 1
        #{k : 0 for k in domain_counts.keys()}
        counter += 1
        if counter == n_batches:
            return indices_seen, domain_counts
        #idxs = batch[0][:, 0].tolist()
        #classes = batch[0][:, 1]
        #class_ids, class_counts = classes.unique(return_counts=True)
        #class_ids = set(class_ids.tolist())
        #class_counts = class_counts.tolist()
        #print(f"Batch {i}: ({class_ids})")

# %%
dl_upsampled = DataLoader(
    yolo_train_ds,
    batch_size=32,
    collate_fn=yolov7_collate_fn,
    sampler=sampler
)
#visualise_dataloader(dl_original)
indices_seen_upsampled, domain_counts_upsampled = print_dataloader(dl_upsampled, n_batches=int(len(train_df_images) // 32))
# Out:
#  98%|█████████▊| 113/115 [02:18<00:02,  1.23s/it]

# %%
from matplotlib import pyplot as plt
plt.bar(domain_counts_upsampled.keys(), domain_counts_upsampled.values())
plt.xticks(rotation=90)
print(len(indices_seen_upsampled))
print(np.sum(list(domain_counts_upsampled.values())))
# Out:
# 3648
# 3648

# %%
dl_original = DataLoader(
    yolo_train_ds,
    batch_size=32,
    collate_fn=yolov7_collate_fn,
    sampler=None
)
indices_seen_original, domain_counts_original = print_dataloader(dl_original, n_batches=int(len(train_df_images) // 32))
# Out:
#  98%|█████████▊| 113/115 [02:29<00:02,  1.32s/it]

# %%
plt.bar(domain_counts_original.keys(), domain_counts_original.values())
plt.xticks(rotation=90)
print(len(indices_seen_original))
print(np.sum(list(domain_counts_original.values())))
# Out:
# 3648
# 3648

# %%
from collections import Counter

image_counts_df = (
    pd.merge(
        train_df_images.reset_index(drop=True)
        .reset_index()
        .rename(columns={"index": "image_idx"}),
        pd.DataFrame.from_records(
            {"image_idx": k, "seen_count": v} for k, v in Counter(indices_seen_upsampled).items()
        ),
        how="left",
    )
    .fillna(0)
    .sort_values("seen_count", ascending=False)
    .reset_index(drop=True)
)
image_counts_df
# Out:
#       image_idx                                         image_name  \
# 0          2199  9ddd23aa23d4f04645e109305e6982239954ff0bbd4180...
# 1          1150  4e5cb9af8ce8b486d908be0979c85698ad08928fce4c62...
# 2          2559  b63e9b7d429546d3053fe69f4e4aba9e3100effd013632...
# 3          2393  aa2907446e0af92d40f9e1081c46897b9a3809b6cec072...
# 4          1670  760bae76d619a48330f05d8ad561fc22be3e53d2923c08...
# ...         ...                                                ...
# 3649       1839  8293ed0446c0a3b606d1984acf8f0e1e07963dc7dfdee0...
# 3650        401  1bc27ea490d08a61352fa0d3fb9ecfb226f37c9e4cf6a1...
# 3651       1841  82b31acb3c7459bdf0f2c8c36bc432149d5329bfd309ea...
# 3652       1844  82d91301629405fa4843f8ee2aa4fe0f1644feeb569f9e...
# 3653       1827  814989f131536769e971d6a12d10edd9270ad0b10c0970...
#
#                                             BoxesString     domain    weight  \
# 0     847 209 923 253;207 297 280 359;147 256 241 31...  Arvalis_8  0.050000
# 1     656 66 753 176;436 242 491 341;459 457 543 551...  Arvalis_8  0.050000
# 2     958 189 1004 237;906 465 978 521;774 331 895 3...  Arvalis_7  0.041667
# 3     729 970 894 1024;834 728 888 807;902 569 1008 ...  Arvalis_7  0.041667
# 4     905 64 954 128;945 134 984 190;934 224 978 279...  Arvalis_8  0.050000
# ...                                                 ...        ...       ...
# 3649  58 660 148 724;0 889 56 991;30 517 99 622;57 3...  Arvalis_5  0.002232
# 3650  688 955 775 1024;697 614 838 713;293 553 394 6...     Rres_1  0.002315
# 3651  399 128 490 200;299 141 391 248;710 307 769 38...  Arvalis_3  0.001701
# 3652  737 65 786 131;417 621 487 671;293 506 361 561...     ETHZ_1  0.001340
# 3653  621 406 711 525;263 805 351 875;565 646 640 74...     Rres_1  0.002315
#
#       seen_count
# 0           17.0
# 1           15.0
# 2           14.0
# 3           14.0
# 4           14.0
# ...          ...
# 3649         0.0
# 3650         0.0
# 3651         0.0
# 3652         0.0
# 3653         0.0
#
# [3654 rows x 6 columns]

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 10))
for domain in domains_names:
    sns.ecdfplot(image_counts_df.query(f'domain == "{domain}"').seen_count, ax=ax, label=domain)
ax.set_xlabel("Number of times seen during training", fontsize=12)
ax.set_ylabel("Proportion of images in the dataset", fontsize=12)
ax.legend(fontsize=12)
ax.set_title("ECDF Plot showing how often images were seen during training")
fig.tight_layout()
fig.show()
# Out:
# /tmp/ipykernel_54254/3452290043.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
